# %%
from functions import *

os.environ["CUDA_VISIBLE_DEVICES"] = "0"
FEATURE                          = "raw"
__DATASET__                      = 'sets/cicids_'+FEATURE+'.h5' 
CHECKPOINT_NAME                  = 'raw'

# %%
classifier = CLSmodel(__DATASET__, CHECKPOINT_NAME, kfold=True)

# %%
classifier.pipeline(batch_size=10240, epochs=100, numfolds=5, upsampling=CHECKPOINT_NAME)
# Out:
# accuracy
# 	training         	 (min:    0.889, max:    1.000, cur:    1.000)
# 	validation       	 (min:    0.855, max:    1.000, cur:    1.000)
# f1_score
# 	training         	 (min:    0.200, max:    0.912, cur:    0.910)
# 	validation       	 (min:    0.130, max:    0.906, cur:    0.864)
# Loss
# 	training         	 (min:    0.001, max:    0.489, cur:    0.001)
# 	validation       	 (min:    0.002, max:    0.373, cur:    0.002)
#
# Epoch 00100: val_f1_score did not improve from 0.90633
# 221/221 [==============================] - 7s 29ms/step - loss: 9.4179e-04 - accuracy: 0.9996 - f1_score: 0.9100 - val_loss: 0.0017 - val_accuracy: 0.9995 - val_f1_score: 0.8641
#
# ###########
# predicting...
# ###########
#
#               precision    recall  f1-score   support
#
#            0   0.999974  0.999861  0.999917    454264 BENIGN
#            1   0.999544  0.999609  0.999576     46024 DoS Hulk
#            2   0.997464  1.000000  0.998730      1180 SSH-Patator
# ...

# %%
classifier.X.shape, classifier.Y.shape

# %%
all_labels = ['BENIGN', 'DoS Hulk', 'SSH-Patator', 'PortScan', 'DoS GoldenEye', 
              'DDoS', 'Heartbleed', 'Web Attack Brute Force', 'FTP-Patator', 
              'Web Attack XSS', 'DoS slowloris', 'Infiltration', 'Bot', 
              'Web Attack Sql Injection', 'DoS Slowhttptest']

# %%
for i in range(len(all_labels)):
    print("{} : {}".format(
        all_labels[i],
        classifier.Y[classifier.Y == i].shape[0],
    ))

# %%
classifier.summary()

# %%
classifier.load_model('results/checkpoint/classifier_raw_fold-1.hdf5')

# %%
classifier.model.summary()

# %%
train_set = []
for i in range(len(labels)):
    train_set.append(len(class[i].samples))

train_set.sort(according_to=num_samples)
desired_num_samples = train_set[int(len(train_set)/2)]

# %%
5796 * .8

# %%
total = 0
for i in train_set.sort(according_to=num_samples)
result += classifier.X[classifier.Y == i[0]].shape[0]

                desired_num_samples = int(result / len(list(all_sets_tmp.items())[1:]))

# %%
desired_num_samples

# %%
len(list(all_sets_tmp.items())[1:])

# %%
2+2
# Out:
# 4
